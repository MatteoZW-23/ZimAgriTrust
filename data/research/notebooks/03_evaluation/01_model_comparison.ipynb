# %%
"""
NOTEBOOK: MODEL COMPARISON
===========================
Purpose: Compare multiple models to select best performing
Output: Model selection recommendations
"""

# %% [markdown]
# # 📊 Model Comparison Notebook
#
# **Objective:** Compare ARIMA, Prophet, LSTM for price prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsmodels.tsa.arima.model import ARIMA
from prophet import Prophet
import torch

class ModelComparator:
    """Compare different model performances"""
    
    def __init__(self):
        self.results = {}
    
    def train_arima(self, series):
        """Train ARIMA model"""
        model = ARIMA(series, order=(5, 1, 0))
        model_fit = model.fit()
        return model_fit
    
    def train_prophet(self, df):
        """Train Prophet model"""
        model = Prophet()
        model.fit(df)
        return model
    
    def load_lstm_model(self, path):
        """Load pre-trained LSTM model"""
        # Load from saved weights
        return None
    
    def evaluate(self, y_true, y_pred, model_name):
        """Evaluate model performance"""
        mae = mean_absolute_error(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
        
        self.results[model_name] = {
            'MAE': mae,
            'RMSE': rmse,
            'MAPE': mape,
            'Accuracy': 100 - mape
        }
        
        return self.results[model_name]
    
    def compare_all(self, train_data, test_data):
        """Run comparison across all models"""
        print("📊 Comparing Models...")
        
        # ARIMA
        arima_model = self.train_arima(train_data)
        arima_pred = arima_model.forecast(steps=len(test_data))
        self.evaluate(test_data, arima_pred, 'ARIMA')
        
        # Prophet
        prophet_df = pd.DataFrame({'ds': test_data.index, 'y': test_data.values})
        # Would need proper training here
        
        print("\n📈 Comparison Results:")
        results_df = pd.DataFrame(self.results).T
        print(results_df)
        
        # Find best model
        best_model = results_df['Accuracy'].idxmax()
        print(f"\n🏆 Best Model: {best_model} with {results_df.loc[best_model, 'Accuracy']:.1f}% accuracy")
        
        return results_df

print("\n✅ Model comparison loaded!")
